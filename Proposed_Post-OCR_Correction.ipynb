# %% [markdown]
# # Modified Spelling Correction Algorithm for Detecting and Tracking Errors

# %%
#Original spelling correction algorithm (http://norvig.com/spell-correct.html)
import re, csv
from collections import Counter


def words(text): return re.findall(r'\w+', text.lower())


WORDS = Counter(words(open('./blog_test.txt').read()))


def P(word, N=sum(WORDS.values())):
    "Probability of `word`."
    return WORDS[word] / N


def correction(word):
    "Most probable spelling correction for word."
    return max(candidates(word), key=P)

def candidates(word):
    "Generate possible spelling corrections for word."
    return known([word]) or known(edits1(word)) or known(edits2(word)) or [word]


def known(words):
    "The subset of `words` that appear in the dictionary of WORDS."
    return set(w for w in words if w in WORDS)


def edits1(word):
    "All edits that are one edit away from `word`."
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)


def edits2(word):
    "All edits that are two edits away from `word`."
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))

# %% [markdown]
# # Proposed code for tracking the detected error

# %%
#Proposed code for traking the detected error
def correct_word(word):
    original_word = word
    correction_dictionary = {'Original_word': original_word, 'correction':'',
                             'symbol_chars': 0, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
    # Search for symbols, decode them and try correction on decoded word
    decoded_word, symbols_count = decode(word)
    if symbols_count > 0:
        correction_dictionary['symbol_chars'] += symbols_count
        # Try correction after decode
        if correction(decoded_word) == decoded_word and decoded_word in WORDS:
            correction_dictionary['correction'] = decoded_word
            print('Input word is: {}, possible match is: {}, {}'\
                .format(original_word, decoded_word, correction_dictionary))
            return correction_dictionary
        # If we still didn't get a match after decode,
        # then we will use the decoded word for more analysis
        else:
            word = decoded_word

    # Try deleteDuplicates
    if deleteDuplicates(word):
        duplicates_dictionary = deleteDuplicates(word)
        for trimmed_word in duplicates_dictionary:
            if correction(trimmed_word) == trimmed_word and trimmed_word in WORDS:
                correction_dictionary['repeated_chars'] += duplicates_dictionary.get(trimmed_word)
                correction_dictionary['correction'] = trimmed_word
                print('Input word is: {}, possible match is: {}, {}' \
                    .format(original_word, trimmed_word, correction_dictionary))
                return correction_dictionary
        # If we still didn't get a match after deleteDuplicates,
        # then we will use the deleteDuplicates word for more analysis
        # if there are trimmed duplicates
        if duplicates_dictionary.get(trimmed_word) > 0:
            correction_dictionary['repeated_chars'] += duplicates_dictionary.get(trimmed_word)
            word = trimmed_word

    # Try transpose
    transposes = transpose(word)
    for transposed_word in transposes:
        if correction(transposed_word) == transposed_word and transposed_word in WORDS:
            correction_dictionary['swap_chars'] += 1
            correction_dictionary['correction'] = transposed_word
            print('Input word is: {}, possible match is: {}, {}' \
                .format(original_word, transposed_word, correction_dictionary))
            return correction_dictionary

    # Otherwise, we will match the exact input word
    # or the suggested correction of input word
    # if it exists in the wordlist
    if original_word in WORDS:
        print('Input word {} is correct, {}'.format(original_word, correction_dictionary))
        correction_dictionary['correction'] = original_word
        return correction_dictionary
    if correction(original_word) in WORDS:
        correction_dictionary['correction'] = correction(original_word)
        print('Input word is: {}, possible match is: {}. {}' \
            .format(original_word, correction(original_word), correction_dictionary))
        return correction_dictionary

    # If nothing found, we will inform the user
    correction_dictionary['correction'] = original_word
    correction_dictionary['UNK'] += 1
    print('Input word is: {}, can not be found. {}'.format(original_word, correction_dictionary))
    
    return correction_dictionary

# %%
def decode(word):
    letters_map = {'@': 'a', '$': 's', '!': 'i', '1': 'l', '0': 'o'}
    symbol_chars = 0
    word = list(word)
    for i in range(len(word)):
        if word[i] in letters_map:
            word[i] = letters_map.get(word[i])
            symbol_chars += 1
    return ''.join(word), symbol_chars


def deleteDuplicates(word):
    dups_dictionary = {word: 0}
    splits = [(word[:i], word[i:]) for i in range(1, len(word))]
    deletes = [L + R[1:] for L, R in splits if L[-1] == R[0]]
    if len(deletes) > 0:
        repeated_chars = 1
        dups_dictionary[deletes[0]] = repeated_chars
        # Try to remove any other duplicates like removing other o's in shooow
        while len(deletes) > 1:
            word = list(set(deletes))[0]
            splits = [(word[:i], word[i:]) for i in range(1, len(word))]
            deletes = [L + R[1:] for L, R in splits if L[-1] == R[0]]
            repeated_chars += 1
            dups_dictionary[deletes[0]] = repeated_chars
        return dups_dictionary
    return None


def transpose(word):
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R) > 1]
    return transposes

# %%
#Correcting text in csv file
def csv_correction(csv_filename):
    # Read input file and save the list into input_list variable
    with open(csv_filename, 'r', encoding='utf-8-sig') as input_file:
        try:
            input_list = [row[0] for row in csv.reader(input_file)]
        except:
            print('Error opening input file')

    # Save output list
    fieldNames = ['Original_word', 'correction', 'symbol_chars', 'repeated_chars', 'swap_chars', 'UNK']
    csvfile = open('./data/output_spam-2.csv', 'w')
    writer = csv.DictWriter(csvfile, fieldnames=fieldNames, delimiter=',')
    writer.writeheader()

    # Fill the output file
    for current_row in input_list:
        # If the input is a sentence
        if len(current_row.split(' ')) > 1:
            sentence_dictionary = {'Original_word': current_row, 'correction': '',
                                   'symbol_chars': 0, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
            print('Start of words in "{}"'.format(current_row))
            for w in current_row.split(' '):
                print('***', end='')
                word_correction = correct_word(w)
                if len(sentence_dictionary['correction']) == 0:
                    sentence_dictionary['correction'] = word_correction['correction']
                    sentence_dictionary['UNK'] = word_correction['correction']
                else:
                    sentence_dictionary['correction'] += ' ' + word_correction['correction']

                sentence_dictionary['symbol_chars'] += word_correction['symbol_chars']
                sentence_dictionary['repeated_chars'] += word_correction['repeated_chars']
                sentence_dictionary['swap_chars'] += word_correction['swap_chars']
            writer.writerow(sentence_dictionary)
            print('End of words in "{}"'.format(current_row))
        else:
            writer.writerow(correct_word(current_row))
    csvfile.close()

# %%
correct_word('vi@gra')
# Out:
# Input word is: vi@gra, possible match is: viagra, {'Original_word': 'vi@gra', 'correction': 'viagra', 'symbol_chars': 1, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# {'Original_word': 'vi@gra',
#  'correction': 'viagra',
#  'symbol_chars': 1,
#  'repeated_chars': 0,
#  'swap_chars': 0,
#  'UNK': 0}

# %%
# Testing on csv file
csv_correction('./attacks/C2.csv')
# Out:
# Input word is: m0b!le, possible match is: mobile, {'Original_word': 'm0b!le', 'correction': 'mobile', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: c1@im, possible match is: claim, {'Original_word': 'c1@im', 'correction': 'claim', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: $t0p, possible match is: stop, {'Original_word': '$t0p', 'correction': 'stop', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: rep1y, possible match is: reply, {'Original_word': 'rep1y', 'correction': 'reply', 'symbol_chars': 1, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: pr!ze, possible match is: prize, {'Original_word': 'pr!ze', 'correction': 'prize', 'symbol_chars': 1, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: ju$t, possible match is: just, {'Original_word': 'ju$t', 'correction': 'just', 'symbol_chars': 1, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: c@$h, possible match is: cash, {'Original_word': 'c@$h', 'correction': 'cash', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: w0n, possible match is: won, {'Original_word': 'w0n', 'correction': 'won', 'symbol_chars': 1, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: $end, possible match is: send, {'Original_word': '$end', 'correction': 'send', 'symbol_chars': 1, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: n0k!a, can not be found. {'Original_word': 'n0k!a', 'correction': 'n0k!a', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 1}
# Input word is: w!n, possible match is: win, {'Original_word': 'w!n', 'correction': 'win', 'symbol_chars': 1, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: t0ne, possible match is: tone, {'Original_word': 't0ne', 'correction': 'tone', 'symbol_chars': 1, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: c0nt@ct, possible match is: contact, {'Original_word': 'c0nt@ct', 'correction': 'contact', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: $erv!ce, possible match is: service, {'Original_word': '$erv!ce', 'correction': 'service', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: gu@r@nteed, possible match is: guaranteed, {'Original_word': 'gu@r@nteed', 'correction': 'guaranteed', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: m$g, possible match is: mag. {'Original_word': 'm$g', 'correction': 'mag', 'symbol_chars': 1, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: cu$t0mer, possible match is: customer, {'Original_word': 'cu$t0mer', 'correction': 'customer', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: ph0ne, possible match is: phone, {'Original_word': 'ph0ne', 'correction': 'phone', 'symbol_chars': 1, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: ch@t, possible match is: chat, {'Original_word': 'ch@t', 'correction': 'chat', 'symbol_chars': 1, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: m!n, possible match is: man. {'Original_word': 'm!n', 'correction': 'man', 'symbol_chars': 1, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: dr@w, possible match is: draw, {'Original_word': 'dr@w', 'correction': 'draw', 'symbol_chars': 1, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: @w@rded, possible match is: awarded, {'Original_word': '@w@rded', 'correction': 'awarded', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: c0m, possible match is: com, {'Original_word': 'c0m', 'correction': 'com', 'symbol_chars': 1, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: m!n$, possible match is: many. {'Original_word': 'm!n$', 'correction': 'many', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: 1@test, possible match is: latest, {'Original_word': '1@test', 'correction': 'latest', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: 1!ne, possible match is: line, {'Original_word': '1!ne', 'correction': 'line', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: rece!ve, possible match is: receive, {'Original_word': 'rece!ve', 'correction': 'receive', 'symbol_chars': 1, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: c@mer@, possible match is: camera, {'Original_word': 'c@mer@', 'correction': 'camera', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: me$$age, possible match is: message, {'Original_word': 'me$$age', 'correction': 'message', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: h01iday, possible match is: holiday, {'Original_word': 'h01iday', 'correction': 'holiday', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: v!de0, possible match is: video, {'Original_word': 'v!de0', 'correction': 'video', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: c0$t, possible match is: cost, {'Original_word': 'c0$t', 'correction': 'cost', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: $h0ws, possible match is: shows, {'Original_word': '$h0ws', 'correction': 'shows', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: 1@ndline, possible match is: landline, {'Original_word': '1@ndline', 'correction': 'landline', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: c0de, possible match is: code, {'Original_word': 'c0de', 'correction': 'code', 'symbol_chars': 1, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: r!ngt0ne, possible match is: ringtone, {'Original_word': 'r!ngt0ne', 'correction': 'ringtone', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: b0x, possible match is: box, {'Original_word': 'b0x', 'correction': 'box', 'symbol_chars': 1, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: 1!ve, possible match is: live, {'Original_word': '1!ve', 'correction': 'live', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: $m$, possible match is: sms, {'Original_word': '$m$', 'correction': 'sms', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
# Input word is: @w@rded, possible match is: awarded, {'Original_word': '@w@rded', 'correction': 'awarded', 'symbol_chars': 2, 'repeated_chars': 0, 'swap_chars': 0, 'UNK': 0}
